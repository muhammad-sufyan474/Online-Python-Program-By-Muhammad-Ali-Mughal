# %%
# 11.Write a Python program to get the largest number from a numeric list.

numeric_list = [43,87,90,58,12,82,50,38,27];
numeric_list.sort();
print(numeric_list);
print("The largest number from a numeric list: ", numeric_list[-1]);
# Out:
# [12, 27, 38, 43, 50, 58, 82, 87, 90]
# The largest number from a numeric list:  90
