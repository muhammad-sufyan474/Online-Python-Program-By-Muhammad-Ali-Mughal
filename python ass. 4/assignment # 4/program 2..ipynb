# %%
# 2. Write a program to check if there is any numeric value in list using for loop.

my_list = ['chair',23,'cat',9,4,'apple'];

for i in my_list:
    
    if i == 23:
        print("exist");
    
    else:
          ("nonexist");
# Out:
# exist
