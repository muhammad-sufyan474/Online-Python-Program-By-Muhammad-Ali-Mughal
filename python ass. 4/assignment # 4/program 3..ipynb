# %%
# 3. Write a Python script to add a key to a dictionary.

dictionary = {'ahmed':1550 , 'abid':9853}
print(dictionary);
print("\n");
dictionary.update({'javed':8785})
print(dictionary);
# Out:
# {'ahmed': 1550, 'abid': 9853}
#
#
# {'ahmed': 1550, 'abid': 9853, 'javed': 8785}
