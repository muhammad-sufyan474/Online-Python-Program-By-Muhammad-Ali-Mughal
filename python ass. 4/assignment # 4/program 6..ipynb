# %%
#  6. Write a Python script to check if a given key already exists in a dictionary.

dictionary = {'apples':25,'oranges':43,'bananas':32,'pear':20}

if "oranges" in dictionary.keys():
    print("This key exists in dictionary");
else:
    print("This key doesnot exists in dictionary");
# Out:
# This key exists in dictionary
