# %%
#  5. Write a program to identify duplicate values from list.

data_list = [75,8,23,53,23,54,45,45,8,75,43,32,22,54,11,43,43]
identify_duplicates = Counter(data_list)

duplicates = list([item for item in identify_duplicates if identify_duplicates[item]>1])
print(duplicates);
# Out:
# [75, 8, 23, 54, 45, 43]
